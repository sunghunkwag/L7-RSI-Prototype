# %%
# Mount Google Drive to save your evolved algorithms
from google.colab import drive
import os

try:
    drive.mount('/content/drive', force_remount=True)
    WORK_DIR = '/content/drive/MyDrive/L7_RSI_Experiments'
except Exception as e:
    print(f"⚠️ Drive Mount Failed: {e}")
    print("📂 Using temporary local storage instead.")
    WORK_DIR = '/content/L7_RSI_Experiments'

os.makedirs(WORK_DIR, exist_ok=True)
os.chdir(WORK_DIR)
print(f"✅ Working Directory set to: {os.getcwd()}")

# %%
# 🚀 ONE-CLICK SETUP & RUN
# This cell will: 
# 1. Clean up old files
# 2. Clone the latest code from GitHub
# 3. Run the RSI Evolution Loop

import os
print("🔄 Initializing L7-RSI Environment...")

# 1. Force Clean & Clone
# !rm -rf L7-RSI-Prototype
# !git clone https://github.com/sunghunkwag/L7-RSI-Prototype.git

# 2. Enter Directory
# %cd L7-RSI-Prototype

# 3. Execute RSI System (with logs enabled)
print("🚀 Starting Evolution Loop...")
# !python L7_RSI_FINAL.py --meta_rounds 5000 --workers 2 --validate 100
